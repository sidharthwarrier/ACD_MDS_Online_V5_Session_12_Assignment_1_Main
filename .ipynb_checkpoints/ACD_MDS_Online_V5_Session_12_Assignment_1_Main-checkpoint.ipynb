# %% [markdown]
# <p>Read the following data set:</p>
# <p>https://archive.ics.uci.edu/ml/machine-learning-databases/adult/</p>
# <p>Rename the columns as per the description from this file:</p>
# <p>https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.names</p>
# <p>Task:</p>
# <p>Create a sql db from adult dataset and name it sqladb</p>

# %%
#Import librires
import pandas as pd
import sqlite3
#Read CSV and checnge column name
df=pd.read_csv(r'C:\Users\sidha\Documents\GitHub\ACD_MDS_Online_V5_Session_12_Assignment_1_Main\adult_data.csv')
df.columns=['age','workclass','fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','capital_gain'
           ,'capital_loss','hours_per_week','native_country','salary']
#Create sqlite connectino to db sqladb
conn = sqlite3.connect('sqladb1.db')
cur = conn.cursor()
#Create table and insert data to table
cur.execute("create table adult (age integer,workclass text,fnlwgt integer,education test ,education_num integer ,marital_status text,occupation text,relationship text,race text,sex text,capital_gain integer,capital_loss integer,hours_per_week integer,native_country text,salary text)")
df.to_sql('adult', conn, if_exists='append', index = False)

# %%
df.head(10)
# Out:
#    age          workclass  fnlwgt      education  education_num  \
# 0   50   Self-emp-not-inc   83311      Bachelors             13
# 1   38            Private  215646        HS-grad              9
# 2   53            Private  234721           11th              7
# 3   28            Private  338409      Bachelors             13
# 4   37            Private  284582        Masters             14
# 5   49            Private  160187            9th              5
# 6   52   Self-emp-not-inc  209642        HS-grad              9
# 7   31            Private   45781        Masters             14
# 8   42            Private  159449      Bachelors             13
# 9   37            Private  280464   Some-college             10
#
#            marital_status          occupation    relationship    race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
df.columns=['age','workclass','fnlwgt','education','educationnum','maritalstatus','occupation','relationship','race','sex','capitalgain'
           ,'capitalloss','hoursperweek','nativecountry','misc']

# %% [markdown]
# <p>Create a sql db from adult dataset and name it sqladb</p>
# <p>1. Select 10 records from the adult sqladb</p>

# %%
pd.read_sql_query("SELECT * FROM adult LIMIT 5;",conn)
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital_status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  salary
# 0             0             0              13   United-States   <=50K
# ...

# %% [markdown]
# 2. Show me the average hours per week of all men who are working in private sector

# %%
pd.read_sql_query("SELECT avg(hours_per_week) FROM adult Where sex =' Male' ;", conn)
# Out:
# average hours per week of all men who are working in private sector is :[(42.428197714443066,)]
#    avg(hours_per_week)
# 0            42.428198

# %% [markdown]
# 3. Show me the frequency table for education, occupation and relationship, separately

# %%
#Educationa and frequency
pd.read_sql_query("select education_num,count(education_num) as Frequency from adult group by education_num ",conn)
# Out:
#     education_num  Frequency
# 0               1         51
# 1               2        168
# 2               3        333
# 3               4        646
# 4               5        514
# 5               6        933
# 6               7       1175
# 7               8        433
# 8               9      10501
# 9              10       7291
# 10             11       1382
# 11             12       1067
# 12             13       5354
# 13             14       1723
# 14             15        576
# 15             16        413

# %%
#Occupatin and frequency
pd.read_sql_query("select occupation,count(occupation) as Frequency from adult group by occupation ",conn)
# Out:
#             occupation  Frequency
# 0                    ?       1843
# 1         Adm-clerical       3769
# 2         Armed-Forces          9
# 3         Craft-repair       4099
# 4      Exec-managerial       4066
# 5      Farming-fishing        994
# 6    Handlers-cleaners       1370
# 7    Machine-op-inspct       2002
# 8        Other-service       3295
# 9      Priv-house-serv        149
# 10      Prof-specialty       4140
# 11     Protective-serv        649
# 12               Sales       3650
# 13        Tech-support        928
# 14    Transport-moving       1597

# %%
#Relationship and frequency
pd.read_sql_query("select relationship,count(relationship) as Frequency from adult group by relationship ",conn)
# Out:
#       relationship  Frequency
# 0          Husband      13193
# 1    Not-in-family       8304
# 2   Other-relative        981
# 3        Own-child       5068
# 4        Unmarried       3446
# 5             Wife       1568

# %% [markdown]
# 4. Are there any people who are married, working in private sector and having a masters
# degree

# %%
#people who are married, working in private sector and having a masters degree
pd.read_sql_query("select count(*) as count from adult where marital_status like ' Married%' and workclass=' Private' and education =' Masters'",conn)
# Out:
#    count
# 0    540

# %% [markdown]
# 5. What is the average, minimum and maximum age group for people working in
# different sectors

# %%
#average, minimum and maximum age group for people working in different sectors
pd.read_sql_query("select avg(age) average,max(age) maximum,min(age) minimum from adult",conn)
# Out:
#      average  maximum  minimum
# 0  38.581634       90       17

# %% [markdown]
# 6. Calculate age distribution by country

# %%
#age distribution by country
pd.read_sql_query("select native_country,age,count(age) from adult group by age , native_country ",conn)
# Out:
#            native_country  age  count(age)
# 0                       ?   17           2
# 1                  Canada   17           2
# 2             El-Salvador   17           2
# 3                 England   17           1
# 4                   Haiti   17           1
# 5                   India   17           1
# 6                  Mexico   17           6
# 7                    Peru   17           2
# 8             Philippines   17           1
# 9                  Poland   17           1
# 10            Puerto-Rico   17           1
# 11        Trinadad&Tobago   17           1
# 12          United-States   17         374
# 13                      ?   18           8
# 14               Cambodia   18           1
# 15                 Canada   18           1
# 16               Columbia   18           1
# 17     Dominican-Republic   18           1
# 18                Germany   18           1
# 19               Honduras   18           1
# 20                  India   18           1
# ...

# %% [markdown]
# 7. Compute a new column as 'Net-Capital-Gain' from the two columns 'capital-gain' and
# 'capital-loss'

# %%
#Create column Net_Capital_Gain
cur.execute("alter table adult add column Net_Capital_Gain integer;")
#Update colum net capital gain
cur.execute("update adult  set Net_Capital_Gain= capital_gain-capital_loss ")
pd.read_sql_query("select fnlwgt,Net_Capital_Gain from adult where Net_Capital_Gain > 0",conn)
# Out:
#       fnlwgt  Net_Capital_Gain
# 0      45781             14084
# 1     159449              5178
# 2     188146              5013
# 3      59496              2407
# 4     343591             14344
# 5     198282             15024
# 6     317660              7688
# 7     304873             34095
# 8     377869              4064
# 9     120985              4386
# 10     56795             14084
# 11    138992              7298
# 12    128757              7298
# 13    210563             15024
# 14    167687              1409
# 15    538583              3674
# 16    146013              4064
# 17    191260              1055
# 18     30653              2407
# 19    170924              7298
# 20    279472              7298
# 21     97688              5178
# 22    425161             15024
# 23    157443              3464
# 24    146268              7688
# 25    238638              4386
# 26    142897              7298
# 27    127921              2050
# 28    296478              7298
# ...

# %%
sqladb
# Out:
#     age          workclass  fnlwgt      education  educationnum  \
# 0    50   Self-emp-not-inc   83311      Bachelors            13
# 1    38            Private  215646        HS-grad             9
# 2    53            Private  234721           11th             7
# 3    28            Private  338409      Bachelors            13
# 4    37            Private  284582        Masters            14
# 5    49            Private  160187            9th             5
# 6    52   Self-emp-not-inc  209642        HS-grad             9
# 7    31            Private   45781        Masters            14
# 8    42            Private  159449      Bachelors            13
# 9    37            Private  280464   Some-college            10
# 10   30          State-gov  141297      Bachelors            13
# 11   23            Private  122272      Bachelors            13
# 12   32            Private  205019     Assoc-acdm            12
# 13   40            Private  121772      Assoc-voc            11
# ...

# %%
cur.execute("drop table adult")

# %%
conn.close()
